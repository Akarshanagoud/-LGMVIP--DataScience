# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings("ignore")

# %%
stk = pd.read_csv("nse.csv")

# %%
stk.head() # Prints first Five Rows
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
stk.tail() # Prints last five rows
# Out:
#             Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2030  2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
# 2031  2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2032  2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2033  2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2034  2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
#
#       Turnover (Lacs)
# 2030           694.98
# 2031           780.01
# 2032           340.31
# 2033           355.17
# 2034           803.56

# %%
stk.describe() # Gives Statistical information like Mean, Median, Count, Standard deviation, Minimum value, Maximum value
# Out:
#               Open         High          Low         Last       Close  \
# count  2035.000000  2035.000000  2035.000000  2035.000000  2035.00000
# mean    149.713735   151.992826   147.293931   149.474251   149.45027
# std      48.664509    49.413109    47.931958    48.732570    48.71204
# min      81.100000    82.800000    80.000000    81.000000    80.95000
# 25%     120.025000   122.100000   118.300000   120.075000   120.05000
# 50%     141.500000   143.400000   139.600000   141.100000   141.25000
# 75%     157.175000   159.400000   155.150000   156.925000   156.90000
# max     327.700000   328.750000   321.650000   325.950000   325.75000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          2.035000e+03      2035.000000
# mean           2.335681e+06      3899.980565
# std            2.091778e+06      4570.767877
# min            3.961000e+04        37.040000
# 25%            1.146444e+06      1427.460000
# 50%            1.783456e+06      2512.030000
# 75%            2.813594e+06      4539.015000
# max            2.919102e+07     55755.080000

# %%
stk.isnull() # Calculating null values in the Dataset
# Out:
#        Date   Open   High    Low   Last  Close  Total Trade Quantity  \
# 0     False  False  False  False  False  False                 False
# 1     False  False  False  False  False  False                 False
# 2     False  False  False  False  False  False                 False
# 3     False  False  False  False  False  False                 False
# 4     False  False  False  False  False  False                 False
# ...     ...    ...    ...    ...    ...    ...                   ...
# 2030  False  False  False  False  False  False                 False
# 2031  False  False  False  False  False  False                 False
# 2032  False  False  False  False  False  False                 False
# 2033  False  False  False  False  False  False                 False
# 2034  False  False  False  False  False  False                 False
#
#       Turnover (Lacs)
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# ...               ...
# 2030            False
# 2031            False
# 2032            False
# 2033            False
# 2034            False
#
# [2035 rows x 8 columns]

# %%
stk['Date']=pd.to_datetime(stk['Date'])
print(type(stk.Date[0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df=stk.sort_values(by='Date')
df.head()
# Out:
#            Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2034 2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
# 2033 2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2032 2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2031 2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2030 2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
#
#       Turnover (Lacs)
# 2034           803.56
# 2033           355.17
# 2032           340.31
# 2031           780.01
# 2030           694.98

# %%
df.reset_index(inplace=True) # Reset the index of the Dataframe

# %%
df.head()
# Out:
#    index       Date   Open    High     Low    Last   Close  \
# 0   2034 2010-07-21  122.1  123.00  121.05  121.10  121.55
# 1   2033 2010-07-22  120.3  122.00  120.25  120.75  120.90
# 2   2032 2010-07-23  121.8  121.95  120.25  120.35  120.65
# 3   2031 2010-07-26  120.1  121.00  117.10  117.10  117.60
# 4   2030 2010-07-27  117.6  119.50  112.00  118.80  118.65
#
#    Total Trade Quantity  Turnover (Lacs)
# 0                658666           803.56
# 1                293312           355.17
# 2                281312           340.31
# 3                658440           780.01
# 4                586100           694.98

# %%
plt.plot(df['Close'])

# %%
dff=df['Close']
dff
# Out:
# 0       121.55
# 1       120.90
# 2       120.65
# 3       117.60
# 4       118.65
#          ...
# 2030    233.30
# 2031    236.10
# 2032    234.25
# 2033    233.25
# 2034    233.75
# Name: Close, Length: 2035, dtype: float64

# %%
scaler=MinMaxScaler(feature_range=(0,1))
dff=scaler.fit_transform(np.array(dff).reshape(-1,1))
dff
# Out:
# array([[0.16584967],
#        [0.16319444],
#        [0.1621732 ],
#        ...,
#        [0.62622549],
#        [0.62214052],
#        [0.62418301]])

# %%
training_size=int(len(dff)*0.70)
test_size=len(dff)-training_size
train_data,test_data=dff[0:training_size,:],dff[training_size:len(dff),:1]

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (1323, 100)
# (1323,)
# (None, None)

# %%
print(X_test.shape), print(ytest.shape)
# Out:
# (510, 100)
# (510,)
# (None, None)

# %%
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_split=0.1,epochs=60,batch_size=64,verbose=1)
# Out:
# Epoch 1/60
# 19/19 [==============================] - 8s 191ms/step - loss: 0.0085 - val_loss: 0.0025
# Epoch 2/60
# 19/19 [==============================] - 2s 129ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 3/60
# 19/19 [==============================] - 2s 130ms/step - loss: 9.2860e-04 - val_loss: 0.0012
# Epoch 4/60
# 19/19 [==============================] - 3s 146ms/step - loss: 8.3348e-04 - val_loss: 0.0013
# Epoch 5/60
# 19/19 [==============================] - 3s 133ms/step - loss: 8.3197e-04 - val_loss: 0.0010
# Epoch 6/60
# 19/19 [==============================] - 3s 132ms/step - loss: 7.8745e-04 - val_loss: 0.0010
# Epoch 7/60
# 19/19 [==============================] - 3s 133ms/step - loss: 7.4498e-04 - val_loss: 9.6733e-04
# Epoch 8/60
# 19/19 [==============================] - 3s 135ms/step - loss: 7.2274e-04 - val_loss: 9.3149e-04
# Epoch 9/60
# 19/19 [==============================] - 3s 152ms/step - loss: 6.8055e-04 - val_loss: 8.3707e-04
# Epoch 10/60
# 19/19 [==============================] - 3s 141ms/step - loss: 6.4494e-04 - val_loss: 8.1714e-04
# Epoch 11/60
# 19/19 [==============================] - 3s 138ms/step - loss: 6.2625e-04 - val_loss: 7.3005e-04
# Epoch 12/60
# 19/19 [==============================] - 3s 139ms/step - loss: 6.3482e-04 - val_loss: 7.0194e-04
# Epoch 13/60
# 19/19 [==============================] - 3s 140ms/step - loss: 6.0388e-04 - val_loss: 7.7266e-04
# Epoch 14/60
# 19/19 [==============================] - 3s 138ms/step - loss: 5.8887e-04 - val_loss: 6.4172e-04
# Epoch 15/60
# 19/19 [==============================] - 3s 158ms/step - loss: 5.7679e-04 - val_loss: 7.0240e-04
# Epoch 16/60
# 19/19 [==============================] - 3s 164ms/step - loss: 5.4373e-04 - val_loss: 5.9801e-04
# Epoch 17/60
# 19/19 [==============================] - 3s 165ms/step - loss: 5.3598e-04 - val_loss: 5.8256e-04
# Epoch 18/60
# 19/19 [==============================] - 3s 163ms/step - loss: 5.1704e-04 - val_loss: 5.5610e-04
# Epoch 19/60
# 19/19 [==============================] - 4s 190ms/step - loss: 5.1114e-04 - val_loss: 5.8358e-04
# Epoch 20/60
# 19/19 [==============================] - 3s 169ms/step - loss: 4.9365e-04 - val_loss: 5.6584e-04
# Epoch 21/60
# 19/19 [==============================] - 3s 166ms/step - loss: 4.7959e-04 - val_loss: 5.2735e-04
# Epoch 22/60
# 19/19 [==============================] - 3s 161ms/step - loss: 4.7639e-04 - val_loss: 5.0377e-04
# Epoch 23/60
# 19/19 [==============================] - 3s 174ms/step - loss: 4.7987e-04 - val_loss: 4.9054e-04
# Epoch 24/60
# 19/19 [==============================] - 3s 177ms/step - loss: 4.7797e-04 - val_loss: 4.5338e-04
# Epoch 25/60
# 19/19 [==============================] - 3s 181ms/step - loss: 4.2849e-04 - val_loss: 4.5425e-04
# Epoch 26/60
# 19/19 [==============================] - 3s 166ms/step - loss: 4.3309e-04 - val_loss: 4.6071e-04
# Epoch 27/60
# 19/19 [==============================] - 3s 158ms/step - loss: 4.0952e-04 - val_loss: 4.5170e-04
# Epoch 28/60
# 19/19 [==============================] - 3s 158ms/step - loss: 3.9343e-04 - val_loss: 4.0321e-04
# Epoch 29/60
# 19/19 [==============================] - 3s 157ms/step - loss: 3.8767e-04 - val_loss: 3.6640e-04
# Epoch 30/60
# 19/19 [==============================] - 3s 162ms/step - loss: 3.9771e-04 - val_loss: 3.7475e-04
# Epoch 31/60
# 19/19 [==============================] - 3s 163ms/step - loss: 3.7442e-04 - val_loss: 3.7992e-04
# Epoch 32/60
# 19/19 [==============================] - 3s 158ms/step - loss: 3.4898e-04 - val_loss: 3.6927e-04
# Epoch 33/60
# 19/19 [==============================] - 3s 158ms/step - loss: 3.5229e-04 - val_loss: 3.4203e-04
# Epoch 34/60
# 19/19 [==============================] - 3s 158ms/step - loss: 3.2992e-04 - val_loss: 3.4324e-04
# Epoch 35/60
# 19/19 [==============================] - 3s 157ms/step - loss: 3.7996e-04 - val_loss: 3.2251e-04
# Epoch 36/60
# 19/19 [==============================] - 3s 160ms/step - loss: 3.3083e-04 - val_loss: 3.8600e-04
# Epoch 37/60
# 19/19 [==============================] - 3s 158ms/step - loss: 3.1486e-04 - val_loss: 2.8472e-04
# Epoch 38/60
# 19/19 [==============================] - 3s 158ms/step - loss: 3.0909e-04 - val_loss: 2.7801e-04
# Epoch 39/60
# 19/19 [==============================] - 3s 157ms/step - loss: 3.1013e-04 - val_loss: 2.6373e-04
# Epoch 40/60
# 19/19 [==============================] - 3s 156ms/step - loss: 2.7798e-04 - val_loss: 2.7764e-04
# Epoch 41/60
# 19/19 [==============================] - 3s 159ms/step - loss: 2.7005e-04 - val_loss: 2.3165e-04
# Epoch 42/60
# 19/19 [==============================] - 3s 160ms/step - loss: 2.8332e-04 - val_loss: 2.5961e-04
# Epoch 43/60
# 19/19 [==============================] - 3s 157ms/step - loss: 3.0125e-04 - val_loss: 2.6305e-04
# Epoch 44/60
# 19/19 [==============================] - 3s 157ms/step - loss: 2.9898e-04 - val_loss: 2.2688e-04
# Epoch 45/60
# 19/19 [==============================] - 3s 156ms/step - loss: 2.7195e-04 - val_loss: 2.9667e-04
# Epoch 46/60
# 19/19 [==============================] - 3s 157ms/step - loss: 2.9881e-04 - val_loss: 3.5534e-04
# Epoch 47/60
# 19/19 [==============================] - 3s 155ms/step - loss: 2.8916e-04 - val_loss: 3.1824e-04
# Epoch 48/60
# 19/19 [==============================] - 3s 158ms/step - loss: 2.7230e-04 - val_loss: 2.2345e-04
# Epoch 49/60
# 19/19 [==============================] - 3s 155ms/step - loss: 2.4973e-04 - val_loss: 1.9846e-04
# Epoch 50/60
# 19/19 [==============================] - 3s 156ms/step - loss: 2.2799e-04 - val_loss: 2.0529e-04
# Epoch 51/60
# 19/19 [==============================] - 3s 157ms/step - loss: 2.3064e-04 - val_loss: 2.6451e-04
# Epoch 52/60
# 19/19 [==============================] - 3s 158ms/step - loss: 2.2673e-04 - val_loss: 1.9218e-04
# Epoch 53/60
# 19/19 [==============================] - 3s 156ms/step - loss: 2.0606e-04 - val_loss: 1.9228e-04
# Epoch 54/60
# 19/19 [==============================] - 3s 161ms/step - loss: 2.3343e-04 - val_loss: 3.2758e-04
# Epoch 55/60
# 19/19 [==============================] - 3s 155ms/step - loss: 2.3319e-04 - val_loss: 1.9922e-04
# Epoch 56/60
# 19/19 [==============================] - 3s 156ms/step - loss: 2.4140e-04 - val_loss: 2.3371e-04
# Epoch 57/60
# 19/19 [==============================] - 3s 155ms/step - loss: 2.2328e-04 - val_loss: 2.1076e-04
# Epoch 58/60
# 19/19 [==============================] - 3s 157ms/step - loss: 1.9064e-04 - val_loss: 1.6453e-04
# Epoch 59/60
# 19/19 [==============================] - 3s 158ms/step - loss: 1.8311e-04 - val_loss: 1.6445e-04
# Epoch 60/60
# 19/19 [==============================] - 3s 155ms/step - loss: 1.8688e-04 - val_loss: 1.7678e-04

# %%
test_predict=model.predict(X_test)

# %%
test_predicted=scaler.inverse_transform(test_predict)
test_predicted
# Out:
# array([[140.51724 ],
#        [140.61992 ],
#        [139.56857 ],
#        [136.62976 ],
#        [135.01147 ],
#        [134.84792 ],
#        [136.50526 ],
#        [138.30179 ],
#        [138.41428 ],
#        [137.55186 ],
#        [137.05228 ],
#        [138.44298 ],
#        [139.48955 ],
#        [141.23735 ],
#        [143.56465 ],
#        [141.03236 ],
#        [138.07855 ],
#        [137.93977 ],
#        [139.18791 ],
#        [145.09769 ],
#        [149.81982 ],
#        [151.24669 ],
#        [150.52312 ],
#        [147.69348 ],
#        [147.73047 ],
#        [148.2004  ],
#        [149.11858 ],
#        [151.0775  ],
#        [151.60226 ],
#        [151.08405 ],
#        [151.16049 ],
#        [149.762   ],
#        [146.16689 ],
#        [140.1049  ],
#        [136.93346 ],
#        [136.70267 ],
#        [137.42409 ],
#        [136.51653 ],
#        [133.61824 ],
#        [129.37978 ],
#        [126.8418  ],
#        [126.11434 ],
#        [124.41967 ],
#        [123.855125],
#        [121.89664 ],
#        [119.20551 ],
#        [118.63064 ],
#        [118.617676],
#        [119.09543 ],
#        [118.16154 ],
#        [117.16223 ],
#        [116.72658 ],
#        [115.95286 ],
#        [116.18092 ],
#        [117.70802 ],
#        [119.659935],
#        [121.607994],
#        [122.1666  ],
#        [121.570465],
#        [121.37411 ],
#        [121.56152 ],
#        [121.507034],
#        [121.81402 ],
#        [122.30427 ],
#        [122.5206  ],
#        [122.49426 ],
#        [122.18889 ],
#        [122.43339 ],
#        [122.89975 ],
#        [123.251205],
#        [122.36407 ],
#        [121.22148 ],
#        [119.794655],
#        [118.574356],
#        [117.35755 ],
#        [117.65752 ],
#        [118.4367  ],
#        [119.48803 ],
#        [120.54188 ],
#        [121.667114],
#        [122.70297 ],
#        [123.27896 ],
#        [123.61882 ],
#        [123.571075],
#        [123.38819 ],
#        [123.1662  ],
#        [124.091225],
#        [124.567276],
#        [125.56928 ],
#        [126.35092 ],
#        [126.636   ],
#        [126.931404],
#        [127.842186],
#        [127.3188  ],
#        [126.63564 ],
#        [126.51981 ],
#        [126.76552 ],
#        [127.3596  ],
#        [128.33318 ],
#        [128.53996 ],
#        [128.6269  ],
#        [131.44197 ],
#        [136.33765 ],
#        [140.45847 ],
#        [141.66687 ],
#        [142.61494 ],
#        [142.46248 ],
#        [141.83813 ],
#        [140.61249 ],
#        [139.44899 ],
#        [138.004   ],
#        [137.66626 ],
#        [138.17476 ],
#        [139.39215 ],
#        [140.35767 ],
#        [139.99785 ],
#        [138.77762 ],
#        [137.61974 ],
#        [136.73322 ],
#        [138.58131 ],
#        [140.06166 ],
#        [141.27296 ],
#        [141.81389 ],
#        [141.56618 ],
#        [140.52353 ],
#        [139.38022 ],
#        [137.30591 ],
#        [136.66982 ],
#        [137.77858 ],
#        [140.73427 ],
#        [143.24588 ],
#        [144.84373 ],
#        [145.01651 ],
#        [143.23523 ],
#        [144.99194 ],
#        [147.88597 ],
#        [148.49818 ],
#        [148.37505 ],
#        [148.26224 ],
#        [148.10953 ],
#        [148.20805 ],
#        [149.0277  ],
#        [150.1614  ],
#        [151.02008 ],
#        [150.17604 ],
#        [149.06024 ],
#        [149.64923 ],
#        [150.10043 ],
#        [149.49791 ],
#        [148.21474 ],
#        [146.7595  ],
#        [146.90802 ],
#        [148.69455 ],
#        [149.89848 ],
#        [150.31415 ],
#        [150.06494 ],
#        [150.5903  ],
#        [150.56407 ],
#        [150.62819 ],
#        [152.89789 ],
#        [154.4936  ],
#        [154.29393 ],
#        [151.9647  ],
#        [150.10132 ],
#        [150.32173 ],
#        [151.81772 ],
#        [152.61873 ],
#        [151.91838 ],
#        [151.78716 ],
#        [152.08638 ],
#        [151.61833 ],
#        [148.49641 ],
#        [146.60725 ],
#        [145.8026  ],
#        [144.4476  ],
#        [142.04654 ],
#        [140.90807 ],
#        [142.68124 ],
#        [144.33948 ],
#        [144.86157 ],
#        [146.18616 ],
#        [148.71619 ],
#        [151.63634 ],
#        [153.22798 ],
#        [152.39104 ],
#        [152.0465  ],
#        [152.00523 ],
#        [152.0326  ],
#        [151.0619  ],
#        [152.12775 ],
#        [154.79784 ],
#        [157.0345  ],
#        [157.29039 ],
#        [155.57954 ],
#        [154.17459 ],
#        [153.81819 ],
#        [153.16336 ],
#        [150.9229  ],
#        [147.36646 ],
#        [145.94952 ],
#        [146.13577 ],
#        [147.74796 ],
#        [149.54999 ],
#        [149.6808  ],
#        [151.57558 ],
#        [152.31546 ],
#        [153.8537  ],
#        [159.31497 ],
#        [165.41771 ],
#        [170.30713 ],
#        [172.68759 ],
#        [171.96614 ],
#        [171.9137  ],
#        [170.9037  ],
#        [170.79393 ],
#        [169.35834 ],
#        [168.59837 ],
#        [167.61679 ],
#        [167.613   ],
#        [168.61049 ],
#        [167.31218 ],
#        [165.8917  ],
#        [165.6172  ],
#        [164.90881 ],
#        [163.00183 ],
#        [162.46083 ],
#        [162.89781 ],
#        [165.47874 ],
#        [165.25346 ],
#        [161.57904 ],
#        [155.59949 ],
#        [156.26228 ],
#        [167.3824  ],
#        [185.17616 ],
#        [193.1961  ],
#        [192.55815 ],
#        [190.1365  ],
#        [185.53287 ],
#        [187.15762 ],
#        [189.68378 ],
#        [189.9778  ],
#        [187.3719  ],
#        [189.42422 ],
#        [192.92433 ],
#        [193.83228 ],
#        [190.06216 ],
#        [188.99226 ],
#        [195.84947 ],
#        [201.08466 ],
#        [201.87581 ],
#        [201.82265 ],
#        [203.61241 ],
#        [201.90776 ],
#        [202.90286 ],
#        [203.78035 ],
#        [205.51306 ],
#        [208.27423 ],
#        [207.6555  ],
#        [204.9306  ],
#        [196.37537 ],
#        [188.97888 ],
#        [192.96025 ],
#        [194.8144  ],
#        [196.2415  ],
#        [198.32664 ],
#        [199.48923 ],
#        [198.30788 ],
#        [199.97057 ],
#        [202.04243 ],
#        [201.78998 ],
#        [200.9555  ],
#        [201.42957 ],
#        [203.91988 ],
#        [204.23749 ],
#        [202.82979 ],
#        [202.40065 ],
#        [200.53105 ],
#        [197.88322 ],
#        [195.99532 ],
#        [200.02962 ],
#        [200.7231  ],
#        [201.80545 ],
#        [209.53146 ],
#        [218.46873 ],
#        [220.66302 ],
#        [218.86566 ],
#        [216.54912 ],
#        [215.5906  ],
#        [222.59962 ],
#        [220.6396  ],
#        [215.56952 ],
#        [225.03981 ],
#        [229.83095 ],
#        [226.20746 ],
#        [231.28401 ],
#        [239.16072 ],
#        [241.51967 ],
#        [245.39468 ],
#        [257.96957 ],
#        [261.57315 ],
#        [258.89877 ],
#        [258.00427 ],
#        [262.17813 ],
#        [263.4226  ],
#        [269.8565  ],
#        [266.54358 ],
#        [267.62225 ],
#        [267.10678 ],
#        [262.61157 ],
#        [261.6739  ],
#        [258.98846 ],
#        [264.4536  ],
#        [270.6392  ],
#        [277.8366  ],
#        [270.46066 ],
#        [262.90817 ],
#        [263.8106  ],
#        [268.6943  ],
#        [272.61032 ],
#        [279.46506 ],
#        [280.83392 ],
#        [278.5492  ],
#        [280.14102 ],
#        [284.56677 ],
#        [285.34848 ],
#        [285.0907  ],
#        [292.72552 ],
#        [292.81854 ],
#        [288.84177 ],
#        [288.40778 ],
#        [290.7157  ],
#        [291.87088 ],
#        [294.82788 ],
#        [293.57086 ],
#        [291.25058 ],
#        [290.68158 ],
#        [300.91443 ],
#        [301.8514  ],
#        [293.31967 ],
#        [289.2515  ],
#        [285.0653  ],
#        [286.85327 ],
#        [288.512   ],
#        [286.1127  ],
#        [282.1014  ],
#        [281.5782  ],
#        [280.63705 ],
#        [281.7766  ],
#        [271.8493  ],
#        [266.1338  ],
#        [257.28577 ],
#        [253.80818 ],
#        [249.94247 ],
#        [258.67813 ],
#        [262.9506  ],
#        [258.78424 ],
#        [261.4706  ],
#        [262.44702 ],
#        [259.7268  ],
#        [256.37466 ],
#        [250.69307 ],
#        [245.81322 ],
#        [248.64467 ],
#        [247.76558 ],
#        [251.98518 ],
#        [256.28528 ],
#        [257.33682 ],
#        [256.88226 ],
#        [256.41333 ],
#        [257.4743  ],
#        [257.27576 ],
#        [252.94592 ],
#        [254.81013 ],
#        [253.49374 ],
#        [257.53018 ],
#        [261.43085 ],
#        [261.39    ],
#        [260.9598  ],
#        [255.74602 ],
#        [244.94661 ],
#        [243.73843 ],
#        [247.93169 ],
#        [245.74759 ],
#        [241.80008 ],
#        [244.14737 ],
#        [247.66306 ],
#        [244.12912 ],
#        [254.94495 ],
#        [260.12714 ],
#        [254.33798 ],
#        [253.04442 ],
#        [255.44797 ],
#        [260.70386 ],
#        [260.3056  ],
#        [256.9255  ],
#        [256.09738 ],
#        [258.33286 ],
#        [262.4277  ],
#        [264.02933 ],
#        [265.4836  ],
#        [267.34042 ],
#        [267.79816 ],
#        [265.46597 ],
#        [264.3418  ],
#        [269.49237 ],
#        [273.31277 ],
#        [273.2552  ],
#        [276.28632 ],
#        [274.12967 ],
#        [267.6363  ],
#        [267.4075  ],
#        [274.55713 ],
#        [273.11832 ],
#        [271.30386 ],
#        [266.38724 ],
#        [266.8417  ],
#        [244.3221  ],
#        [224.72021 ],
#        [223.89914 ],
#        [233.39203 ],
#        [233.56992 ],
#        [227.87729 ],
#        [228.01599 ],
#        [232.74783 ],
#        [238.0804  ],
#        [241.66383 ],
#        [244.08185 ],
#        [242.34814 ],
#        [246.53612 ],
#        [253.49727 ],
#        [250.7555  ],
#        [241.15326 ],
#        [245.03293 ],
#        [252.21114 ],
#        [253.99939 ],
#        [251.81834 ],
#        [248.03738 ],
#        [250.26164 ],
#        [254.18607 ],
#        [260.7995  ],
#        [257.94547 ],
#        [256.6538  ],
#        [251.64696 ],
#        [245.20514 ],
#        [242.4242  ],
#        [246.1714  ],
#        [249.91699 ],
#        [251.52667 ],
#        [249.36903 ],
#        [246.69435 ],
#        [250.70302 ],
#        [249.92924 ],
#        [260.2464  ],
#        [262.77542 ],
#        [255.00362 ],
#        [248.03336 ],
#        [255.47636 ],
#        [260.6432  ],
#        [255.3945  ],
#        [248.00476 ],
#        [242.5069  ],
#        [230.82306 ],
#        [230.50446 ],
#        [227.56946 ],
#        [220.7002  ],
#        [222.08865 ],
#        [228.5988  ],
#        [232.83026 ],
#        [225.47499 ],
#        [222.0942  ],
#        [226.56212 ],
#        [230.16885 ],
#        [233.5623  ],
#        [226.23495 ],
#        [221.13669 ],
#        [221.60732 ],
#        [227.10283 ],
#        [228.21184 ],
#        [225.40263 ],
#        [224.44032 ],
#        [222.5652  ],
#        [222.46948 ],
#        [225.40431 ],
#        [228.22276 ],
#        [231.02583 ],
#        [233.06471 ],
#        [229.83875 ],
#        [223.82138 ],
#        [219.14928 ],
#        [223.40533 ],
#        [224.77228 ],
#        [223.89922 ],
#        [224.03857 ],
#        [223.2438  ],
#        [224.28502 ],
#        [216.0628  ],
#        [209.99495 ],
#        [209.49559 ],
#        [212.57442 ],
#        [213.47273 ],
#        [208.31963 ],
#        [209.49733 ],
#        [220.48305 ],
#        [228.11133 ],
#        [226.50128 ],
#        [222.91212 ],
#        [222.23032 ],
#        [222.70412 ],
#        [225.21867 ],
#        [225.22075 ]], dtype=float32)

# %%
import math
from sklearn.metrics import mean_squared_error

# %%
performance = math.sqrt(mean_squared_error(ytest,test_predict))
performance
# Out:
# 0.05035563088250859
